isKGK5dmdIngG40tjwnEvHAzkNQeWaD1P4dDccCFUIrkwoMlsUtnesxe5u2J2wpGguEcF-CoXMg7ybi4002Dmd31e2jttsAPFtFR0deaXV7T3DgbEbnlf9mUGBMA27cTWd3zfINur2oRUkZHwb4UOm3SoLy_9FQpFzcjxBW8QMb4RMyTXcO7sluXwDkRl_ybDh3YuPALbZmXmajw3VPJOddSA5W6Qx3vmAI7ol1HXI4wiZMSowhBoe1XZbVPBcmjWTAfgMFA84aB-sDsqYJzx1aY5yNCwoP9dJfTHnAumIlfvvqRbxQA.xY7FLnCtWiAsOZFjzlD-aw"

# %%
res = requests.post(f"{JP_API_URL}/v1/token/auth_refresh?refreshtoken={JPQ_TOKEN}")
if res.status_code == 200:
	id_token = res.json()['idToken']
	headers = {'Authorization': 'Bearer {}'.format(id_token)}
	display("fresh idToken")
else:
	display(res.json()["message"])
# Out:
# 'fresh idToken'

# %%
USER_DATA = {
	"mailaddress"	: "Ohboy3947@gmail.com",
	"password"		: "R2E6VxnFytiY8zC"
}

# %%
try:
	res = requests.post(f"{JP_API_URL}/v1/token/auth_user", data=json.dumps(USER_DATA))
	refresh_token = res.json()['refreshToken']
except:
	print("Failed to get a RefreshToken")
else:
	# id token取得
	try:
		res = requests.post(f"{JP_API_URL}/v1/token/auth_refresh?refreshtoken={refresh_token}")
		id_token = res.json()['idToken']
	except:
		print("Failed to get an idToken")
	else:
		headers = {'Authorization': 'Bearer {}'.format(id_token)}
		print("Preparation is completed")
# Out:
# Preparation is completed

# %%
id_token
refresh_token
JPQ_TOKEN
refresh_token == JPQ_TOKEN
# Out:
# 'eyJraWQiOiJHQXNvU2xxUzMyUktLT2lVYm1xcjU3ekdYNE1TVFhsWFBrbDNJTmhWKzNzPSIsImFsZyI6IlJTMjU2In0.....ZUiZhGl-FdYgSDPNNCaHUh0Zyl8UMOYkTnP7DNWCJyWNkVGkBqExZ2UP8KfSm2U50kcQn3CVC5p4H6c1P-D7ZJeKJdwRFZW3zcinhTMUVzco1sdYZByzCS7DNLkjZahFVMHpnIFXTEjew6BPOXPDThuvvbKYaf8G70gsYFGDkOjy0jaWKeYph7rFpBjSgQAgEMVNoo9IPsV0qH682c7llbTrv8Mcm3OKj_TuFvT9QzLjeUjn0k-ApokQxN30FHrr6TedLBId8N5LgRka7uKDZKlTbjPh9aGmL4qBssHAj0UE_-BIUCZyVElAVBNHNPFScLgNkNWKoLgP35VbGCTk8g'
# 'eyJjdHkiOiJKV1QiLCJlbmMiOiJBMjU2R0NNIiwiYWxnIjoiUlNBLU9BRVAifQ.uhBrr2-dFde1sNHjVQlhdHVvt4ebN876zUyDlPyaUnW8mU8W8-uE8poYwtMdLKcl2j3O2Q2yAffTz8RvGg4SDVAcUQ2TeQZym1Leoazyy3KkLfwihMZJBvkVsH8eC_jWa-RnZKBI3ZvUnmb0muSC4GWhDClWRR1HwZ8_iQSBG29fkU6iL
40tjwnEvHAzkNQeWaD1P4dDccCFUIrkwoMlsUtnesxe5u2J2wpGguEcF-CoXMg7ybi4002Dmd31e2jttsAPFtFR0deaXV7T3DgbEbnlf9mUGBMA27cTWd3zfINur2oRUkZHwb4UOm3SoLy_9FQpFzcjxBW8QMb4RMyTXcO7sluXwDkRl_ybDh3YuPALbZmXmajw3VPJOddSA5W6Qx3vmAI7ol1HXI4wiZMSowhBoe1XZbVPBcmjWTAfgMFA84aB-sDsqYJzx1aY5yNCwoP9dJfTHnAumIlfvvqRbxQA.xY7FLnCtWiAsOZFjzlD-aw'
# False

# %% [markdown]
# - id and refresh token is ready

# %% [markdown]
# #### get universe

# %%
def get_universe_asof_date(date=dt.date.today().strftime("%Y%m%d"), code=""):

	qt.log.info(f"querying universe as of date = {date}, code = {code}")

	# create parameters to send universe request with
	params = {}
	if code != "":
		params["code"] = code
	if date != "":
		params["date"] = date

	# send request
	res = requests.get(f"{JP_API_URL}/v1/listed/info", params=params, headers=headers)

	# dummy result
	df = pd.DataFrame()

	# if request is successful, get all data with pagination
	if res.status_code == 200:
		d = res.json()
		data = d["info"]
		while "pagination_key" in d:
			params["pagination_key"] = d["pagination_key"]
			res = requests.get(f"{JP_API_URL}/v1/listed/info", params=params, headers=headers)
			d = res.json()
			data += d["info"]
		
		# create dataframe
		df = pd.DataFrame(data)
		cs = df.columns.tolist()
		df['query_date'] = pd.to_datetime(date).date()
		df = df[['query_date'] + cs]
		df['Date'] = pd.to_datetime(df['Date']).dt.date

	else:
		qt.log.error(f"failed to get universe on date = {date}: {res.status_code} {res.text}")

	return df

# %%
# dfl = [get_universe_asof_date(date=d) for d in pd.date_range(start="2020-01-01", end="2025-12-31", freq="MS").date]
# univ = pd.concat(dfl, ignore_index=True).sort_values('query_date').reset_index(drop=True)
# univ.to_csv("univ_jquants.csv", index=False)

univ = pd.read_csv("univ_jquants.csv")
univ['query_date'] = pd.to_datetime(univ['query_date']).dt.date
univ['Date'] = pd.to_datetime(univ['Date']).dt.date
# Out:
# /tmp/ipykernel_236816/3199008597.py:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   univ = pd.read_csv("univ_jquants.csv")

# %%
pd.DataFrame( univ.value_counts('query_date').sort_index(ascending=True)).plot()

# %%
qt.view(univ[univ['query_date'] == univ['query_date'].max()].reset_index(drop=True))
# Out:
# Grid(columns_fit='auto', compress_data=True, css_rules_down=['.number-cell {text-align: left;width: 10;}', '.l…

# %% [markdown]
# - querying prices

# %%
#@title Stock Prices(OHLC)（/prices/daily_quotes）

#@markdown - Stock price consists before and after adjustment of stock splits and reverse stock splits (Rounded to first decimal places)
#@markdown - In your request message, either "code" or "date" **must** be specified.

#@markdown （Update timing）
#@markdown - Daily, around 17:00


today = dt.date.today().strftime("%Y%m%d")
code = ""#@param {type:"string"}
date = "20200101"#@param {type:"string"}
from_ = "" #@param {type:"string"}
to = "" #@param {type:"string"}

params = {}
if code != "":
	params["code"] = code
if date != "":
	params["date"] = date
if from_ != "":
	params["from"] = from_
if to != "":
	params["to"] = to

res = requests.get(f"{JP_API_URL}/v1/prices/daily_quotes", params=params, headers=headers)

if res.status_code == 200:
	d = res.json()
	data = d["daily_quotes"]
	while "pagination_key" in d:
		params["pagination_key"] = d["pagination_key"]
		res = requests.get(f"{JP_API_URL}/v1/prices/daily_quotes", params=params, headers=headers)
		d = res.json()
		data += d["daily_quotes"]
	df = pd.DataFrame(data)
	# display(df)
else:
	print(res.json())

# %%
params
# Out:
# {'date': '20200101'}

# %% [markdown]
# - short selling

# %%
import jquantsapi

# %%
jqapi = jquantsapi.Client(refresh_token=refresh_token)

# %%
df_list = jqapi.get_list()

# %%
TARGET_SYMBOLS = [
	"7201",  # 日産
	"7203",  # トヨタ
	"7267",  # ホンダ
]
BASE_DATE = "2020-01-01"
TARGET_SYMBOLS  = univ[univ['ScaleCategory'].isin(["TOPIX Core30", "TOPIX Large70"])]['Code'].unique().tolist()
len(TARGET_SYMBOLS)
# Out:
# 221

# %%
buff = []
for code in TARGET_SYMBOLS:
	df = jqapi.get_prices_daily_quotes(code=code)
	buff.append(df)
df_p = pd.concat(buff).reset_index(drop=True)

# 各列のデータ型を調整します
df_p.loc[:, "Date"] = pd.to_datetime(df_p["Date"], format="%Y-%m-%d")
df_p.loc[:, "Open"] = df_p["Open"].astype(np.float64)
df_p.loc[:, "High"] = df_p["High"].astype(np.float64)
df_p.loc[:, "Low"] = df_p["Low"].astype(np.float64)
df_p.loc[:, "Close"] = df_p["Close"].astype(np.float64)
df_p.loc[:, "Volume"] = df_p["Volume"].astype(np.float64)
df_p.loc[:, "TurnoverValue"] = df_p["TurnoverValue"].astype(np.float64)
df_p.loc[:, "AdjustmentFactor"] = df_p["AdjustmentFactor"].astype(np.float64)
df_p.loc[:, "AdjustmentOpen"] = df_p["AdjustmentOpen"].astype(np.float64)
df_p.loc[:, "AdjustmentHigh"] = df_p["AdjustmentHigh"].astype(np.float64)
df_p.loc[:, "AdjustmentLow"] = df_p["AdjustmentLow"].astype(np.float64)
df_p.loc[:, "AdjustmentClose"] = df_p["AdjustmentClose"].astype(np.float64)
df_p.loc[:, "AdjustmentVolume"] = df_p["AdjustmentVolume"].astype(np.float64)

# 日付を絞り込みます
df_p = df_p.loc[df_p["Date"] >= BASE_DATE]

# %%
df_p.to_csv("jpquant_prices_daily_quotes.csv", index=False)

# %%
df_p
# Out:
#              Date   Code      Open      High       Low     Close UpperLimit  \
# 988    2020-01-06  69540 20,030.00 20,120.00 19,845.00 20,000.00          0
# 989    2020-01-07  69540 20,190.00 20,305.00 20,080.00 20,240.00          0
# 990    2020-01-08  69540 19,740.00 19,920.00 19,575.00 19,825.00          0
# 991    2020-01-09  69540 20,195.00 20,245.00 20,120.00 20,195.00          0
# 992    2020-01-10  69540 20,550.00 20,800.00 20,505.00 20,670.00          0
# ...           ...    ...       ...       ...       ...       ...        ...
# 535693 2025-12-10  43070  6,156.00  6,199.00  6,143.00  6,160.00          0
# 535694 2025-12-11  43070  6,186.00  6,206.00  6,096.00  6,162.00          0
# 535695 2025-12-12  43070  6,174.00  6,235.00  6,144.00  6,175.00          0
# 535696 2025-12-15  43070  6,210.00  6,259.00  6,145.00  6,231.00          0
# 535697 2025-12-16  43070  6,169.00  6,179.00  6,102.00  6,117.00          0
#
#        LowerLimit       Volume     TurnoverValue  AdjustmentFactor  \
# 988             0   998,400.00 19,931,338,500.00              1.00
# 989             0   993,000.00 20,078,098,500.00              1.00
# 990             0 1,028,300.00 20,325,198,000.00              1.00
# 991             0   780,100.00 15,756,649,500.00              1.00
# 992             0 1,344,500.00 27,765,519,500.00              1.00
# ...           ...          ...               ...               ...
# 535693          0   672,000.00  4,142,770,700.00              1.00
# 535694          0   898,100.00  5,534,294,900.00              1.00
# 535695          0 1,287,800.00  7,955,870,000.00              1.00
# 535696          0   708,600.00  4,403,468,600.00              1.00
# 535697          0 1,096,800.00  6,726,373,400.00              1.00
#
#         AdjustmentOpen  AdjustmentHigh  AdjustmentLow  AdjustmentClose  \
# 988           4,006.00        4,024.00       3,969.00         4,000.00
# 989           4,038.00        4,061.00       4,016.00         4,048.00
# 990           3,948.00        3,984.00       3,915.00         3,965.00
# 991           4,039.00        4,049.00       4,024.00         4,039.00
# 992           4,110.00        4,160.00       4,101.00         4,134.00
# ...                ...             ...            ...              ...
# 535693        6,156.00        6,199.00       6,143.00         6,160.00
# 535694        6,186.00        6,206.00       6,096.00         6,162.00
# 535695        6,174.00        6,235.00       6,144.00         6,175.00
# 535696        6,210.00        6,259.00       6,145.00         6,231.00
# 535697        6,169.00        6,179.00       6,102.00         6,117.00
#
#         AdjustmentVolume
# 988         4,992,000.00
# 989         4,965,000.00
# 990         5,141,500.00
# 991         3,900,500.00
# 992         6,722,500.00
# ...                  ...
# 535693        672,000.00
# 535694        898,100.00
# 535695      1,287,800.00
# 535696        708,600.00
# 535697      1,096,800.00
#
# [318830 rows x 16 columns]

# %% [markdown]
# - topix data load

# %%
#@title TOPIX Prices(OHLC)（/indices/topix）

#@markdown - Available index is TOPIX（Tokyo Stock Price Index）.
#@markdown - In your request message, "from/to" can be specified.

#@markdown （Update timing）
#@markdown - Daily, around 16:30


date_from = ""#@param {type:"string"}
date_to = ""#@param {type:"string"}

params = {}

if date_from != "":
	params["from"] = date_from
if date_to != "":
	params["to"] = date_to

res = requests.get(f"{JP_API_URL}/v1/indices/topix", params=params, headers=headers)

if res.status_code == 200:
	d = res.json()
	data = d["topix"]
	while "pagination_key" in d:
		params["pagination_key"] = d["pagination_key"]
		res = requests.get(f"{JP_API_URL}/v1/indices/topix", params=params, headers=headers)
		d = res.json()
		data += d["topix"]
	df = pd.DataFrame(data)
	display(df)
else:
	print(res.json())
